# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavyaSriKollati2004/Bhavya-sri/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 13:31:46--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   201MB/s    in 0.3s
#
# 2024-04-06 13:31:49 (201 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8283   1504.06787v4  Deep generative models (DGMs) are effective on...    cs
# 21896   1408.6693v1  The FastICA algorithm is one of the most popul...  stat
# 22306  1512.07548v1  We show that the objective function of convent...  stat
# 11883  1703.04025v2  Learning graphical models from data is an impo...  stat
# 12803  1705.08080v2  A crucial capability of real-world intelligent...    cs
# ...             ...                                                ...   ...
# 2838   1802.06416v1  Mobile network that millions of people use eve...    cs
# 10812   1405.5311v1  Conventional approaches of sampling signals fo...  stat
# 27787  1704.05416v1  We study the problem of deblurring light field...    cs
# 35989   0903.0467v1  We argue that parameterized complexity is a us...    cs
# 14534  cs/0204049v1  We present memory-based learning approaches to...    cs
#
#                                                    title  year  \
# 8283                   Max-margin Deep Generative Models  2015
# 21896  A study of the fixed points and spurious solut...  2014
# 22306         k-Means Clustering Is Matrix Factorization  2015
# 11883  Learning Large-Scale Bayesian Networks with th...  2017
# 12803  Visual Semantic Planning using Deep Successor ...  2017
# ...                                                  ...   ...
# 2838   Sim-To-Real Optimization Of Complex Real World...  2018
# 10812            Compressive Sampling Using EM Algorithm  2014
# 27787                Light Field Blind Motion Deblurring  2017
# 35989  The Parameterized Complexity of Global Constra...  2009
# 14534                       Memory-Based Shallow Parsing  2002
#
#                                                 keywords
# 8283   [generative, effective, multilayered, represen...
# 21896  [algorithm, iterative, algorithms, independent...
# 22306  [objective, conventional, clustering, expresse...
# 11883  [graphical, important, applications, thousands...
# 12803  [capability, intelligent, predicting, observat...
# ...                                                  ...
# 2838   [optimization, exploding, capexopex, challenge...
# 10812  [conventional, approaches, celebrated, compres...
# 27787  [deblurring, theoretical, practical, contribut...
# 35989  [parameterized, complexity, constraints, parti...
# 14534  [approaches, identification, arbitrary, recogn...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8283     [generative, effective, multilayered, represen...
# 21896    [algorithm, iterative, algorithms, independent...
# 22306    [objective, conventional, clustering, expresse...
# 11883    [graphical, important, applications, thousands...
# 12803    [capability, intelligent, predicting, observat...
#                                ...
# 22099    [considers, statistical, estimation, probabili...
# 13529    [classification, popularly, discovery, descrip...
# 35935    [algorithm, presented, traditional, universal,...
# 21289    [advertising, advertisers, performance, achiev...
# 11323    [classification, clustering, important, statis...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8808 words.
# Out of those 4587 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee81bd94-80e4-4322-82bd-5bcfab9f1573" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee81bd94-80e4-4322-82bd-5bcfab9f1573")) {                    Plotly.newPlot(                        "ee81bd94-80e4-4322-82bd-5bcfab9f1573",                        [{"x":["predictions","generative","performance","exploring","prediction","convolutional","subgradient","principle","discriminative","algorithm","performing","multilayered","demonstrate","objective","empirical","retaining","effective","stochastic","significantly","meanwhile","capability","inference","representations","competitive","efficient","recognition","employing","examining","piecewise","practical","inclusion","interested","iterative","understood","completely","nonlinearity","algorithms","occasionally","addressing","extensively","correspond","relationship","investigate","nonlinearities","contribution","distributions","solutions","attractive","community","occurrence","independent","discovered","optimizers","component","scenarios","characterizations","conventional","factorization","frobenius","reference","clustering","approximation","mentioned","difference","literature","expressed","thousands","variables","sometimes","scalability","compatible","important","applications","consistency","structure","implemented","developed","challenge","dimensional","interventions","additionally","graphical","furthermore","preconditions","predicting","predictive","environment","observations","intelligent","transform","interacting","knowledge","affordances","experimental","reinforcement","bootstrapping","successor","generalization","challenging","imitation","programming","outperform","dimensionality","interleaving","identifying","redundant","complexity","selection","computational","dimensions","computations","potentially","characterized","expensive","experiments","approaches","formulates","moderately","irrelevant","quadratic","available","integrating","refinement","computationally","improving","significant","guaranteed","gradually","different","pertaining","properties","following","deliberately","dynamical","diversification","diffusion","pioneering","investigates","mutations","understand","transformations","biological","published","proliferation","simultaneously","stabilizing","projected","penalized","indefinite","formulation","relatively","interpreted","minimizing","classification","technique","efficiently","nonconvex","integration","introduction","signature","fundamental","signatures","contained","represents","characteristic","computation","understanding","theoretical","straightforward","processed","classical","individual","extraction","parametric","summarise","information","converted","discussion","definition","transforms","familiarity","discusses","numerical","embedding","necessary","capturing","representative","conclusion","healthcare","automatically","automated","incorporated","framework","essential","experiment","screening","prerequisite","successfully","categorize","evaluation"],"y":[63,102,920,43,210,418,4,51,102,821,62,2,544,142,124,8,242,127,281,15,52,202,230,125,413,373,36,14,24,133,7,27,68,32,40,5,569,0,24,40,27,58,139,2,71,107,141,20,79,31,119,21,3,102,92,5,98,32,5,47,135,102,14,65,113,33,18,136,22,45,10,358,433,50,341,111,194,147,179,4,70,49,165,2,68,55,124,82,63,68,17,367,6,363,115,12,8,98,256,6,106,103,55,4,88,24,226,146,279,40,33,49,37,59,602,409,4,6,8,29,304,52,19,107,125,233,30,18,735,3,216,80,3,19,2,25,2,27,2,81,47,42,39,1,115,3,19,5,2,83,62,29,41,502,228,162,10,50,20,11,85,5,17,49,33,145,163,149,21,33,100,122,150,28,1,726,8,27,40,23,1,30,72,103,66,37,35,12,14,180,100,22,546,68,65,8,7,95,11,246],"type":"bar"},{"x":["predictions","generative","performance","exploring","pred ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4587,), (4587, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Uncertainty</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>Decision</span> <span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Technique</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Financial</span> <span style=''>Data</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>models</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>outcomes</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>evaluated</span> <span style=''>which</span> <span style=''>is</span> <span style=''>of</span> <span style=''>crucial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>for</span> <span style=''>making</span> <span style=''>reliable</span> <span style='background-color:rgba(0, 255, 0, 0.5342465753424657);'>decisions</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>financial</span> <span style=''>in</span> <span style=''>which</span> <span style=''>risks</span> <span style=''>have</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>between</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>for</span> <span style=''>training</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diversity</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>ensemble</span> <span style=''>and</span> <span style=''>the</span> <span style=''>required</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>models</span> <span style=''>can</span> <span style=''>also</span> <span style=''>give</span> <span style=''>useful</span> <span style='background-color:rgba(0, 255, 0, 0.34444444444444455);'>information</span> <span style=''>for</span> <span style=''>experts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>responsible</span> <span style=''>for</span> <span style=''>making</span> <span style=''>reliable</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>classifications</span> <span style=''>For</span> <span style=''>this</span> <span style=''>reason</span> <span style=''>Decision</span> <span style=''>Trees</span> <span style=''>(DTs)</span> <span style=''>seem</span> <span style=''>to</span> <span style=''>be</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>Belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Propagation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>fixed</span> <span style=''>points</span> <br/><br/><span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>physics</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>over</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>Belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>message</span> <span style=''>passing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>computes</span> <span style=''>exactly</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginals</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style=''>is</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>But</span> <span style=''>it</span> <span style=''>has</span> <span style=''>gained</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularity</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>them</span> <span style=''>in</span> <span style=''>the</span> <span style=''>more</span> <span style=''>general</span> <span style=''>case</span> <span style=''>even</span> <span style=''>if</span> <span style=''>it</span> <span style=''>can</span> <span style=''>exhibits</span> <span style=''>multiple</span> <span style=''>fixed</span> <span style=''>points</span> <span style=''>and</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>express</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>for</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>of</span> <span style=''>a</span> <span style=''>belief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>fixed</span> <span style=''>point</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>the</span> <span style=''>beliefs</span> <span style=''>values</span> <span style=''>at</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Restricted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Boltzmann</span> <span style=''>Machine</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3125);'>Perturbation</span> <br/><br/><span style=''>A</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4754098360655737);'>likelihood</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3422818791946309);'>graphical</span> <span style=''>models</span> <span style=''>and</span> <span style=''>RBM</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>Perturb</span> <span style=''>and</span> <span style=''>Descend</span> <span style=''>(PD)</span> <span style=''>is</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>two</span> <span style=''>ideas</span> <span style=''>(I)</span> <span style=''>perturb</span> <span style=''>and</span> <span style=''>MAP</span> <span style=''>method</span> <span style=''>for</span> <span style=''>sampling</span> <span style=''>(II)</span> <span style=''>learning</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Contrastive</span> <span style='background-color:rgba(255, 0, 0, 0.39024390243902446);'>Divergence</span> <span style='background-color:rgba(255, 0, 0, 0.3509933774834437);'>minimization</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>perturb</span> <span style=''>and</span> <span style=''>MAP</span> <span style=''>PD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>training</span> <span style=''>data</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>models</span> <span style=''>that</span> <span style=''>do</span> <span style=''>not</span> <span style=''>allow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>MAP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>During</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>a</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>the</span> <span style=''>current</span> <span style=''>model</span> <span style=''>we</span> <span style=''>start</span> <span style=''>from</span> <span style=''>a</span> <span style=''>training</span> <span style=''>data</span> <span style=''>and</span> <span style=''>descend</span> <span style=''>in</span> <span style=''>the</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>landscape</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbed</span> <span style=''>model</span> <span style=''>for</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>number</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>or</span> <span style=''>until</span> <span style=''>a</span> <span style=''>local</span> <span style=''>optima</span> <span style=''>is</span> <span style=''>reached</span> <span style=''>For</span> <span style=''>RBM</span> <span style=''>this</span> <span style=''>involves</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818182);'>thresholding</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>New</span> <span style=''>Space</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparing</span> <span style=''>Graphs</span> <br/><br/><span style=''>Finding</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>for</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>is</span> <span style=''>an</span> <span style=''>open</span> <span style=''>ended</span> <span style=''>research</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>Having</span> <span style=''>such</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prerequisite</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>like</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>etc</span> <span style=''>over</span> <span style=''>graph</span> <span style=''>datasets</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>positive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semidefinite</span> <span style=''>matrix</span> <span style=''>with</span> <span style=''>the</span> <span style=''>(ij)</span> <span style=''>th</span> <span style=''>entry</span> <span style=''>equal</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>vectors</span> <span style=''>Aie</span> <span style=''>and</span> <span style=''>Aje</span> <span style=''>(e</span> <span style=''>being</span> <span style=''>vector</span> <span style=''>of</span> <span style=''>all</span> <span style=''>ones)</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>for</span> <span style=''>graph</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style=''>A</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>encodes</span> <span style=''>the</span> <span style=''>spectrum</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>it</span> <span style=''>also</span> <span style=''>contains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10353535353535354)
# 	architecture (0.08152958152958154)
# 	representation (0.12987012987012986)
# 	segmentation (0.07142857142857142)
# 	knowledge (0.1323953823953824)
# 	different (0.26515151515151514)
# 	detection (0.12987012987012986)
# 	information (0.2619047619047619)
# 	recognition (0.13455988455988455)
# 	convolutional (0.15079365079365079)
#
# Some Statistics words are:
# 	optimization (0.18244575936883628)
# 	variables (0.14299802761341224)
# 	algorithm (0.39349112426035504)
# 	statistical (0.15138067061143984)
# 	estimation (0.16814595660749507)
# 	distribution (0.17850098619329388)
# 	theoretical (0.15779092702169625)
# 	dimensional (0.1839250493096647)
# 	inference (0.1952662721893491)
# 	regression (0.17258382642998027)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fca209c1-8595-4454-8ee6-0932d2759db9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fca209c1-8595-4454-8ee6-0932d2759db9")) {                    Plotly.newPlot(                        "fca209c1-8595-4454-8ee6-0932d2759db9",                        [{"x":["predictions","generative","performance","exploring","prediction","convolutional","subgradient","principle","discriminative","algorithm","performing","multilayered","demonstrate","objective","empirical","retaining","effective","stochastic","significantly","meanwhile","capability","inference","representations","competitive","efficient","recognition","employing","examining","piecewise","practical","inclusion","interested","iterative","understood","completely","nonlinearity","algorithms","occasionally","addressing","extensively","correspond","relationship","investigate","nonlinearities","contribution","distributions","solutions","attractive","community","occurrence","independent","discovered","optimizers","component","scenarios","characterizations","conventional","factorization","frobenius","reference","clustering","approximation","mentioned","difference","literature","expressed","thousands","variables","sometimes","scalability","compatible","important","applications","consistency","structure","implemented","developed","challenge","dimensional","interventions","additionally","graphical","furthermore","preconditions","predicting","predictive","environment","observations","intelligent","transform","interacting","knowledge","affordances","experimental","reinforcement","bootstrapping","successor","generalization","challenging","imitation","programming","outperform","dimensionality","interleaving","identifying","redundant","complexity","selection","computational","dimensions","computations","potentially","characterized","expensive","experiments","approaches","formulates","moderately","irrelevant","quadratic","available","integrating","refinement","computationally","improving","significant","guaranteed","gradually","different","pertaining","properties","following","deliberately","dynamical","diversification","diffusion","pioneering","investigates","mutations","understand","transformations","biological","published","proliferation","simultaneously","stabilizing","projected","penalized","indefinite","formulation","relatively","interpreted","minimizing","classification","technique","efficiently","nonconvex","integration","introduction","signature","fundamental","signatures","contained","represents","characteristic","computation","understanding","theoretical","straightforward","processed","classical","individual","extraction","parametric","summarise","information","converted","discussion","definition","transforms","familiarity","discusses","numerical","embedding","necessary","capturing","representative","conclusion","healthcare","automatically","automated","incorporated","framework","essential","experiment","screening","prerequisite","successfully","categorize","evaluation","foundation","assessment","retinopathy","california","invariant","discounting","burdensome","illuminant","degradation","estimation","constancy","application","acquiring","consideration","extensive","synthetic","traditional","sensitivity","variation","represented","differences","notations","techniques","similarities","drawbacks","relevance","advantages","organizing","dissimilarity","combinations","partitioning","reproduce","unbalanced","evolutionary","detection","perfectly","improvement","restricted","constraint","integrate","maintaining","ambiguities","parameters","resolving","modelling","hierarchy","annotations","hierarchical","granularity","correlated","representation","addressed","independently","metrology"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	occasionally
# 	exposition
# 	clarified
# 	crowdworkers
# 	emphsparse
# 	majorization
# 	penalizations
# 	assortativity
# 	physionet
# 	overtraining
# 	debugging
# 	uncontaminated
# 	repulsive
# 	tempering
# 	hausdorff
# 	maximizer
# 	metropolis
# 	bisection
# 	effectivity
# 	underlies
# Some words which never appear in Statistics papers:
# 	affordances
# 	successor
# 	interleaving
# 	deliberately
# 	diversification
# 	retinopathy
# 	illuminant
# 	constancy
# 	infeasibility
# 	pedestrian
# 	deformable
# 	organizers
# 	investigative
# 	rotationally
# 	newsgroups
# 	reinforced
# 	translationally
# 	discontinuity
# 	tracklets
# 	confusing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.095304423190021e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
